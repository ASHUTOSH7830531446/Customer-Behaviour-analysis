# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   Payment Method Frequency of Purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             5050 non-null   int64
#  1   Age                     5050 non-null   int64
#  2   Gender                  5050 non-null   object
#  3   Item Purchased          5050 non-null   object
#  4   Category                5050 non-null   object
#  5   Purchase Amount (USD)   4494 non-null   float64
#  6   Location                5050 non-null   object
#  7   Size                    4680 non-null   object
#  8   Color                   5050 non-null   object
#  9   Season                  5050 non-null   object
#  10  Review Rating           4449 non-null   float64
#  11  Subscription Status     5050 non-null   object
#  12  Shipping Type           5050 non-null   object
#  13  Discount Applied        5050 non-null   object
#  14  Previous Purchases      4502 non-null   float64
#  15  Payment Method          5050 non-null   object
#  16  Frequency of Purchases  5050 non-null   object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 670.8+ KB

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df.describe(include = "all")
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   5050.000000  5050.000000   5050           5050      5050
# unique          NaN          NaN      3             30         5
# top             NaN          NaN   Male          Shirt  Clothing
# freq            NaN          NaN   3018            320      2130
# mean    2519.570891    44.150495    NaN            NaN       NaN
# std     1470.402964    15.282328    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%     1252.250000    31.000000    NaN            NaN       NaN
# 50%     2499.500000    44.000000    NaN            NaN       NaN
# 75%     3740.750000    57.000000    NaN            NaN       NaN
# max     5099.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# count             4494.000000      5050  4680   5050    5050    4449.000000
# unique                    NaN        54     4     25       5            NaN
# top                       NaN  New York     M  Black  Spring            NaN
# freq                      NaN       337  1981    404    1280            NaN
# mean               144.765236       NaN   NaN    NaN     NaN       3.668195
# std                275.590101       NaN   NaN    NaN     NaN       0.865357
# min                 10.120000       NaN   NaN    NaN     NaN       1.000000
# 25%                 41.000000       NaN   NaN    NaN     NaN       3.000000
# 50%                 65.000000       NaN   NaN    NaN     NaN       3.700000
# 75%                 89.000000       NaN   NaN    NaN     NaN       4.400000
# max               1499.760000       NaN   NaN    NaN     NaN       5.000000
#
#        Subscription Status Shipping Type Discount Applied  Previous Purchases  \
# count                 5050          5050             5050         4502.000000
# unique                   2             6                2                 NaN
# top                     No      Standard               No                 NaN
# freq                  3462          1213             2789                 NaN
# mean                   NaN           NaN              NaN           25.221901
# std                    NaN           NaN              NaN           14.521635
# min                    NaN           NaN              NaN            0.000000
# 25%                    NaN           NaN              NaN           13.000000
# 50%                    NaN           NaN              NaN           25.000000
# 75%                    NaN           NaN              NaN           38.000000
# max                    NaN           NaN              NaN           50.000000
#
#        Payment Method Frequency of Purchases
# count            5050                   5050
# unique              6                      7
# top       Credit Card                Monthly
# freq              954                    946
# mean              NaN                    NaN
# std               NaN                    NaN
# min               NaN                    NaN
# 25%               NaN                    NaN
# 50%               NaN                    NaN
# 75%               NaN                    NaN
# max               NaN                    NaN

# %%
df.shape
# Out:
# (5050, 17)

# %% [markdown]
# # Data cleaning

# %%
df['Item Purchased'].unique()
# Out:
# array(['T-shirt', 'Sunglasses', 'Shirt', 'Gloves', 'Jewelry', 'Shorts',
#        'Hat', 'Handbag', 'Shoes', 'Coat', 'Laptop', 'Hoodie', 'Phone',
#        'Jacket', 'Pants', 'Backpack', 'Socks', 'Jeans', 'Bag', 'Belt',
#        'Watch', 'Headphones', 'Blouse', 'Sandals', 'Skirt', 'Sweater',
#        'Scarf', 'Sneakers', 'Boots', 'Dress'], dtype=object)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories    [Sunglasses, Gloves, Jewelry, Hat, Handbag, Ph...
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone,...
# Electronics    [Laptop, Phone, Watch, Bag, Shoes, Shirt, Head...
# Footwear                       [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                         [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories               [Sunglasses, Gloves, Jewelry, Hat, Handbag, Phone, Backpack, Belt, Bag, Headphones, Scarf, Watch, Shirt, Shoes, Laptop]
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone, Pants, Socks, Jeans, Bag, Blouse, Skirt, Sweater, Watch, Laptop, Dress, Headphones]
# Electronics                                                                                 [Laptop, Phone, Watch, Bag, Shoes, Shirt, Headphones]
# Footwear                                                                                                        [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                                                                          [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
correct_mapping = {
    # Clothing
    "T-shirt": "Clothing", "Shirt": "Clothing", "Shorts": "Clothing",
    "Hoodie": "Clothing", "Pants": "Clothing", "Socks": "Clothing",
    "Jeans": "Clothing", "Blouse": "Clothing", "Skirt": "Clothing",
    "Sweater": "Clothing", "Dress": "Clothing",

    # Accessories
    "Sunglasses": "Accessories", "Gloves": "Accessories",
    "Jewelry": "Accessories", "Hat": "Accessories",
    "Handbag": "Accessories", "Backpack": "Accessories",
    "Belt": "Accessories", "Scarf": "Accessories",
    "Bag": "Accessories",

    # Electronics
    "Laptop": "Electronics", "Phone": "Electronics",
    "Headphones": "Electronics", "Watch": "Electronics",

    # Footwear
    "Shoes": "Footwear", "Sandals": "Footwear",
    "Sneakers": "Footwear", "Boots": "Footwear",

    # Outerwear
    "Coat": "Outerwear", "Jacket": "Outerwear"}

# %%
correct_mapping
# Out:
# {'T-shirt': 'Clothing',
#  'Shirt': 'Clothing',
#  'Shorts': 'Clothing',
#  'Hoodie': 'Clothing',
#  'Pants': 'Clothing',
#  'Socks': 'Clothing',
#  'Jeans': 'Clothing',
#  'Blouse': 'Clothing',
#  'Skirt': 'Clothing',
#  'Sweater': 'Clothing',
#  'Dress': 'Clothing',
#  'Sunglasses': 'Accessories',
#  'Gloves': 'Accessories',
#  'Jewelry': 'Accessories',
#  'Hat': 'Accessories',
#  'Handbag': 'Accessories',
#  'Backpack': 'Accessories',
#  'Belt': 'Accessories',
#  'Scarf': 'Accessories',
#  'Bag': 'Accessories',
#  'Laptop': 'Electronics',
#  'Phone': 'Electronics',
#  'Headphones': 'Electronics',
#  'Watch': 'Electronics',
#  'Shoes': 'Footwear',
#  'Sandals': 'Footwear',
#  'Sneakers': 'Footwear',
#  'Boots': 'Footwear',
#  'Coat': 'Outerwear',
#  'Jacket': 'Outerwear'}

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   Payment Method Frequency of Purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %%
df["Category"]=df['Item Purchased'].map(correct_mapping)

# %%
df.groupby("Category")["Item Purchased"].unique()
# Out:
# Category
# Accessories                 [Sunglasses, Gloves, Jewelry, Hat, Handbag, Backpack, Bag, Belt, Scarf]
# Clothing       [T-shirt, Shirt, Shorts, Hoodie, Pants, Socks, Jeans, Blouse, Skirt, Sweater, Dress]
# Electronics                                                      [Laptop, Phone, Watch, Headphones]
# Footwear                                                          [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# # TREATING NULL VALUES
# ##SIZE

# %%
df['Size'].unique()
# Out:
# array(['XL', 'M', 'L', 'S', nan], dtype=object)

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics    [nan, L, S, M, XL]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.groupby('Item Purchased')['Size'].unique()
# Out:
# Item Purchased
# Backpack           [M, S, L, XL]
# Bag           [M, L, nan, XL, S]
# Belt               [M, S, XL, L]
# Blouse             [M, L, S, XL]
# Boots              [L, M, XL, S]
# Coat               [XL, M, S, L]
# Dress              [XL, M, L, S]
# Gloves             [L, M, S, XL]
# Handbag            [S, XL, M, L]
# Hat                [M, L, S, XL]
# Headphones    [S, M, nan, L, XL]
# Hoodie             [M, L, S, XL]
# Jacket             [L, S, M, XL]
# Jeans              [L, M, XL, S]
# Jewelry            [L, XL, M, S]
# Laptop        [nan, M, S, XL, L]
# Pants              [L, M, XL, S]
# Phone         [nan, L, S, M, XL]
# Sandals            [M, S, L, XL]
# Scarf              [M, L, S, XL]
# Shirt         [M, XL, L, S, nan]
# Shoes         [M, L, nan, XL, S]
# Shorts             [S, M, L, XL]
# Skirt              [S, L, M, XL]
# Sneakers           [S, M, L, XL]
# Socks              [M, XL, L, S]
# Sunglasses         [M, L, S, XL]
# Sweater            [M, S, L, XL]
# T-shirt            [XL, M, S, L]
# Watch         [nan, M, L, XL, S]
# Name: Size, dtype: object

# %%
# treating null values or replacing all values in electronic category
df.loc[df['Category']=='Electronics','Size']="NOT APPLICABLE"

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics      [NOT APPLICABLE]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# treating null values or replacing all values in Accessories category
df.loc[df['Category']=="Accessories",'Size']="Free size"

# %%
df.groupby("Category")['Size'].unique()
# Out:
# Category
# Accessories           [Free size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [NOT APPLICABLE]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# treating null values or replacing all values in Footwear category
df.loc[df["Category"]=='Footwear','Size']="Not Applicable"

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [NOT APPLICABLE]
# Footwear         [Not Applicable]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# treating null values or replacing all values in Clothing category
df.loc[(df['Category']=='Clothing')& (df["Size"].isnull()),"Size"] = df[df["Category"]=="Clothing"]["Size"].mode()[0]

# %%
df.groupby("Category")['Size'].unique()
# Out:
# Category
# Accessories         [Free size]
# Clothing          [XL, M, S, L]
# Electronics    [NOT APPLICABLE]
# Footwear       [Not Applicable]
# Outerwear         [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# # Review Rating

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location       Size   Color  Season  \
# 0                   68.0      California         XL   Olive  Winter
# 1                   84.0  South Carolina  Free size   White  Spring
# 2                   50.0         Montana          M   Black  Winter
# 3                   75.0        Illinois  Free size     Red    Fall
# 4                   80.0         Alabama  Free size  Yellow  Spring
#
#    Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0            3.2                  No        Standard               No
# 1            3.9                 Yes   Free Shipping              Yes
# 2            3.1                  No  2-Day Shipping               No
# 3            4.2                  No    Store Pickup               No
# 4            3.6                  No    Store Pickup               No
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                36.0           Cash                 Weekly
# 1                20.0     Debit Card              Quarterly
# 2                18.0           Cash                Monthly
# 3                25.0           Cash               Annually
# 4                17.0    Credit Card                 Weekly

# %%
# mean of review rating
df['Review Rating'].mean()
# Out:
# np.float64(3.668195100022477)

# %%
# median of review rating
df['Review Rating'].median()
# Out:
# np.float64(3.7)

# %%
# mode of review rating
df['Review Rating'].mode()
# Out:
# 0    4.0
# Name: Review Rating, dtype: float64

# %%
df.groupby("Item Purchased")["Review Rating"].mean()
# Out:
# Item Purchased
# Backpack      3.758333
# Bag           3.168539
# Belt          3.762963
# Blouse        3.677647
# Boots         3.813194
# Coat          3.721875
# Dress         3.750000
# Gloves        3.862774
# Handbag       3.771975
# Hat           3.796753
# Headphones    3.075949
# Hoodie        3.716779
# Jacket        3.761446
# Jeans         3.651969
# Jewelry       3.761850
# Laptop        3.191176
# Pants         3.720833
# Phone         2.939024
# Sandals       3.837037
# Scarf         3.702564
# Shirt         3.427273
# Shoes         3.546154
# Shorts        3.722981
# Skirt         3.779747
# Sneakers      3.757931
# Socks         3.755063
# Sunglasses    3.745679
# Sweater       3.768712
# T-shirt       3.790541
# Watch         3.100000
# Name: Review Rating, dtype: float64

# %%
# filling null values of review ratings with the mean of each item purchased
df['Review Rating'] = df['Review Rating'].fillna(df.groupby('Item Purchased')['Review Rating'].transform('mean'))

# %%
df['Review Rating'] = df['Review Rating'].round(2)

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 5045          913   24    Male         Hoodie     Clothing
# 5046         3466   19  Female       Backpack  Accessories
# 5047         3572   70  Female          Skirt     Clothing
# 5048         3195   43  Female       Sneakers     Footwear
# 5049         1832   62    Male         Blouse     Clothing
#
#       Purchase Amount (USD)      Location            Size  Color  Season  \
# 5045                   56.0      Arkansas               M  Green  Winter
# 5046                   53.0          Iowa       Free size   Gold  Spring
# 5047                   27.0  North Dakota               M  White  Summer
# 5048                   52.0      Maryland  Not Applicable   Gold  Summer
# 5049                   71.0         Maine               M   Cyan  Summer
#
#       Review Rating Subscription Status  Shipping Type Discount Applied  \
# 5045            3.4                 Yes   Next Day Air              Yes
# 5046            3.4                  No       Standard               No
# 5047            3.2                  No       Standard               No
# 5048            4.6                  No       Standard               No
# 5049            3.3                  No  Free Shipping               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 5045                32.0  Bank Transfer                Monthly
# 5046                31.0     Debit Card                 Weekly
# 5047                15.0  Bank Transfer         Every 3 Months
# 5048                10.0    Credit Card              Bi-Weekly
# 5049                 5.0  Bank Transfer         Every 3 Months

# %% [markdown]
# # Previous Purchased

# %%
df['Previous Purchases']=df['Previous Purchases'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases          0
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# # PURCHASED AMOUNT

# %%
df.groupby('Item Purchased')['Purchase Amount (USD)'].mean()
# Out:
# Item Purchased
# Backpack       60.111111
# Bag           735.773625
# Belt           59.993902
# Blouse         60.802326
# Boots          62.616438
# Coat           57.851852
# Dress          62.168675
# Gloves         60.550000
# Handbag        57.987261
# Hat            60.787097
# Headphones    831.344565
# Hoodie         58.059603
# Jacket         56.777108
# Jeans          60.456693
# Jewelry        59.011494
# Laptop        805.502027
# Pants          59.005848
# Phone         734.477349
# Sandals        57.527607
# Scarf          61.157233
# Shirt         279.935608
# Shoes         276.343790
# Shorts         60.073620
# Skirt          59.723270
# Sneakers       59.551724
# Socks          58.188679
# Sunglasses     59.975610
# Sweater        57.638554
# T-shirt        63.093333
# Watch         685.231471
# Name: Purchase Amount (USD), dtype: float64

# %%
df['Purchase Amount (USD)']=df['Purchase Amount (USD)'].fillna(df.groupby("Item Purchased")["Purchase Amount (USD)"].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# # checking duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df[df.duplicated()]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 886          2834   43  Female          Jeans     Clothing
# 1402         1621   25    Male            Hat  Accessories
# 1509          974   60    Male         Jacket    Outerwear
# 1600         2135   55    Male        Sandals     Footwear
# 1665         1846   51    Male        Sandals     Footwear
# 1797         3639   40  Female       Backpack  Accessories
# 1870         3456   49  Female        T-shirt     Clothing
# 2033         1812   42    Male           Belt  Accessories
# 2113         3040   59  Female         Blouse     Clothing
# 2226         1371   27    Male          Scarf  Accessories
# 2358         2977   30  Female           Coat    Outerwear
# 2447         2678   45  Female         Shorts     Clothing
# 2630          992   20    Male         Shorts     Clothing
# 2642         1566   58    Male     Sunglasses  Accessories
# 2739         2227   22    Male          Shirt     Clothing
# 2740         3487   51  Female         Shorts     Clothing
# 2800         2069   70    Male        Jewelry  Accessories
# 2905         2158   41    Male        Handbag  Accessories
# 2922         3334   55  Female          Jeans     Clothing
# 3036          258   20    Male        Handbag  Accessories
# 3065         3887   37  Female        Jewelry  Accessories
# 3185         1609   26    Male        Sandals     Footwear
# 3357         3091   29  Female          Shirt     Clothing
# 3390          603   37    Male          Shoes     Footwear
# 3538         1698   36    Male          Shirt     Clothing
# 3683         1209   20    Male          Boots     Footwear
# 3698          172   29    Male         Shorts     Clothing
# 3742          323   41    Male           Belt  Accessories
# 3810         2429   65    Male        T-shirt     Clothing
# 3843          615   68    Male        Jewelry  Accessories
# 3961         2558   70    Male         Shorts     Clothing
# 3987         3507   18  Female          Shirt     Clothing
# 4050         3287   45  Female         Jacket    Outerwear
# 4059          227   29    Male          Shoes     Footwear
# 4131         2642   25    Male     Sunglasses  Accessories
# 4183         1523   38    Male         Shorts     Clothing
# 4330         3716   63  Female     Sunglasses  Accessories
# 4390         3846   58  Female        Sweater     Clothing
# 4445         3644   53  Female          Scarf  Accessories
# 4468          473   20    Male          Jeans     Clothing
# 4513         1317   28    Male           Belt  Accessories
# 4558         3339   29  Female          Skirt     Clothing
# 4595         3577   29  Female          Boots     Footwear
# 4664         2689   53  Female        Handbag  Accessories
# 4717         2800   23  Female        T-shirt     Clothing
# 4735         2182   22    Male        Handbag  Accessories
# 4841         2622   48    Male          Shoes     Footwear
# 4887         3875   70  Female        Sweater     Clothing
# 4901         1060   22    Male         Jacket    Outerwear
# 5037         3439   26  Female          Shirt     Clothing
#
#       Purchase Amount (USD)        Location            Size      Color  \
# 886                    56.0        Arkansas               M       Teal
# 1402                   47.0        Virginia       Free size   Charcoal
# 1509                   75.0        Colorado               M       Teal
# 1600                   41.0        Virginia  Not Applicable     Maroon
# 1665                   78.0        Delaware  Not Applicable     Orange
# 1797                   20.0          Kansas       Free size      Olive
# 1870                   89.0            Ohio               M     Orange
# 2033                   77.0       Wisconsin       Free size       Blue
# 2113                   48.0         Alabama               L       Blue
# 2226                   67.0         Montana       Free size      Peach
# 2358                   97.0        Nebraska               M     Silver
# 2447                   43.0     Connecticut               L      Olive
# 2630                   97.0       Wisconsin              XL      White
# 2642                   93.0           Idaho       Free size      Peach
# 2739                   72.0        Missouri               L       Blue
# 2740                   89.0  North Carolina               L   Charcoal
# 2800                   81.0         Vermont       Free size      Black
# 2905                   68.0     Mississippi       Free size  Turquoise
# 2922                   35.0       Minnesota               M     Violet
# 3036                   53.0   West Virginia       Free size        Red
# 3065                   92.0            Iowa       Free size      Brown
# 3185                   58.0        Nebraska  Not Applicable       Cyan
# 3357                   36.0           Texas               M      Peach
# 3390                   58.0          Oregon  Not Applicable   Lavender
# 3538                   87.0  South Carolina               L   Lavender
# 3683                  100.0       Wisconsin  Not Applicable        Red
# 3698                   35.0        Virginia               M       Blue
# 3742                   95.0       Tennessee       Free size       Cyan
# 3810                   38.0           Idaho               M     Violet
# 3843                   85.0           Idaho       Free size   Lavender
# 3961                   23.0        Oklahoma               L       Cyan
# 3987                   57.0        Illinois               L      Olive
# 4050                   67.0        Illinois               L       Pink
# 4059                   74.0           Texas  Not Applicable     Violet
# 4131                   60.0         Vermont       Free size      Olive
# 4183                   72.0       Tennessee               L     Yellow
# 4330                   34.0        Nebraska       Free size     Orange
# 4390                   52.0      California               M      Green
# 4445                   96.0       Tennessee       Free size    Magenta
# 4468                   39.0         Georgia               L       Gray
# 4513                   32.0        Arkansas       Free size   Lavender
# 4558                   94.0       Minnesota               L      White
# 4595                   24.0           Maine  Not Applicable     Yellow
# 4664                   63.0   West Virginia       Free size  Turquoise
# 4717                   89.0           Maine               L       Pink
# 4735                   63.0          Hawaii       Free size      Black
# 4841                   46.0           Maine  Not Applicable      Beige
# 4887                   54.0          Nevada              XL      Beige
# 4901                   34.0  North Carolina               M      Beige
# 5037                   71.0        Kentucky               M     Violet
#
#       Season  Review Rating Subscription Status   Shipping Type  \
# 886     Fall           3.30                  No   Free Shipping
# 1402  Winter           3.10                  No  2-Day Shipping
# 1509    Fall           3.50                 Yes  2-Day Shipping
# 1600  Winter           2.90                  No        Standard
# 1665  Winter           2.80                  No  2-Day Shipping
# 1797  Spring           4.60                  No         Express
# 1870    Fall           4.70                  No        Standard
# 2033  Summer           3.60                  No        Standard
# 2113  Spring           3.20                  No    Next Day Air
# 2226  Summer           3.70                  No  2-Day Shipping
# 2358  Summer           2.80                  No         Express
# 2447  Spring           3.80                  No    Next Day Air
# 2630  Spring           2.70                 Yes        Standard
# 2642    Fall           4.20                  No   Free Shipping
# 2739  Spring           4.80                  No    Store Pickup
# 2740  Winter           4.90                  No        Standard
# 2800  Summer           3.90                  No    Store Pickup
# 2905  Winter           4.00                  No    Next Day Air
# 2922  Spring           4.20                  No         Express
# 3036  Summer           4.50                 Yes         Express
# 3065  Summer           3.90                  No         Express
# 3185    Fall           4.60                  No    Next Day Air
# 3357  Summer           4.90                  No    Store Pickup
# 3390  Summer           4.20                 Yes    Next Day Air
# 3538    Fall           3.50                  No    Next Day Air
# 3683  Winter           3.81                  No  2-Day Shipping
# 3698  Summer           3.60                 Yes    Store Pickup
# 3742  Winter           3.00                 Yes        Standard
# 3810  Spring           4.40                  No    Next Day Air
# 3843  Winter           4.00                 Yes        Standard
# 3961  Spring           3.90                  No        Standard
# 3987  Winter           3.70                  No  2-Day Shipping
# 4050  Winter           5.00                  No         Express
# 4059  Spring           3.30                 Yes   Free Shipping
# 4131  Winter           2.70                  No    Next Day Air
# 4183  Spring           4.80                  No   Free Shipping
# 4330    Fall           3.40                  No   Free Shipping
# 4390  Winter           4.90                  No        Standard
# 4445    Fall           3.20                  No        Standard
# 4468  Winter           3.90                 Yes   Free Shipping
# 4513  Spring           4.60                  No        Standard
# 4558  Winter           2.90                  No  2-Day Shipping
# 4595  Spring           3.00                  No         Express
# 4664  Spring           2.90                  No  2-Day Shipping
# 4717  Spring           3.90                  No   Free Shipping
# 4735    Fall           3.20                  No   Free Shipping
# 4841  Winter           3.00                  No         Express
# 4887  Summer           3.90                  No  2-Day Shipping
# 4901  Winter           2.50                  No        Standard
# 5037    Fall           3.00                  No    Store Pickup
#
#      Discount Applied  Previous Purchases Payment Method  \
# 886                No                19.0           Cash
# 1402              Yes                27.0         PayPal
# 1509              Yes                30.0  Bank Transfer
# 1600               No                35.0    Credit Card
# 1665               No                39.0  Bank Transfer
# 1797               No                50.0         PayPal
# 1870               No                13.0          Venmo
# 2033               No                33.0  Bank Transfer
# 2113               No                31.0         PayPal
# 2226              Yes                41.0  Bank Transfer
# 2358               No                28.0           Cash
# 2447               No                 6.0         PayPal
# 2630              Yes                40.0  Bank Transfer
# 2642              Yes                48.0         PayPal
# 2739               No                28.0           Cash
# 2740               No                 6.0         PayPal
# 2800               No                44.0          Venmo
# 2905               No                41.0          Venmo
# 2922               No                 3.0         PayPal
# 3036              Yes                 5.0    Credit Card
# 3065               No                40.0     Debit Card
# 3185              Yes                12.0  Bank Transfer
# 3357               No                15.0  Bank Transfer
# 3390              Yes                10.0           Cash
# 3538               No                48.0    Credit Card
# 3683              Yes                 8.0     Debit Card
# 3698              Yes                 4.0    Credit Card
# 3742              Yes                47.0    Credit Card
# 3810               No                34.0     Debit Card
# 3843              Yes                21.0    Credit Card
# 3961               No                17.0         PayPal
# 3987               No                12.0           Cash
# 4050               No                 4.0          Venmo
# 4059              Yes                 5.0         PayPal
# 4131               No                20.0  Bank Transfer
# 4183              Yes                 5.0     Debit Card
# 4330               No                 2.0  Bank Transfer
# 4390               No                46.0          Venmo
# 4445               No                47.0     Debit Card
# 4468              Yes                 3.0  Bank Transfer
# 4513              Yes                14.0     Debit Card
# 4558               No                46.0    Credit Card
# 4595               No                12.0          Venmo
# 4664               No                18.0    Credit Card
# 4717               No                 9.0  Bank Transfer
# 4735               No                32.0  Bank Transfer
# 4841               No                21.0  Bank Transfer
# 4887               No                33.0    Credit Card
# 4901              Yes                25.0     Debit Card
# 5037               No                33.0    Credit Card
#
#      Frequency of Purchases
# 886                 Monthly
# 1402         Every 3 Months
# 1509              Quarterly
# 1600            Fortnightly
# 1665              Quarterly
# 1797              Bi-Weekly
# 1870               Annually
# 2033               Annually
# 2113              Bi-Weekly
# 2226         Every 3 Months
# 2358            Fortnightly
# 2447         Every 3 Months
# 2630              Bi-Weekly
# 2642               Annually
# 2739               Annually
# 2740                 Weekly
# 2800                Monthly
# 2905            Fortnightly
# 2922                Monthly
# 3036              Quarterly
# 3065              Quarterly
# 3185              Bi-Weekly
# 3357              Quarterly
# 3390         Every 3 Months
# 3538         Every 3 Months
# 3683               Annually
# 3698                 Weekly
# 3742                Monthly
# 3810               Annually
# 3843              Bi-Weekly
# 3961            Fortnightly
# 3987            Fortnightly
# 4050            Fortnightly
# 4059                Monthly
# 4131         Every 3 Months
# 4183                Monthly
# 4330                Monthly
# 4390               Annually
# 4445               Annually
# 4468              Quarterly
# 4513              Bi-Weekly
# 4558                Monthly
# 4595              Bi-Weekly
# 4664         Every 3 Months
# 4717         Every 3 Months
# 4735              Bi-Weekly
# 4841               Annually
# 4887              Bi-Weekly
# 4901                Monthly
# 5037                Monthly

# %%
df[df["Customer ID"]==974]
# Out:
#       Customer ID  Age Gender Item Purchased   Category  \
# 483           974   60   Male         Jacket  Outerwear
# 1509          974   60   Male         Jacket  Outerwear
#
#       Purchase Amount (USD)  Location Size Color Season  Review Rating  \
# 483                    75.0  Colorado    M  Teal   Fall            3.5
# 1509                   75.0  Colorado    M  Teal   Fall            3.5
#
#      Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 483                  Yes  2-Day Shipping              Yes                30.0
# 1509                 Yes  2-Day Shipping              Yes                30.0
#
#      Payment Method Frequency of Purchases
# 483   Bank Transfer              Quarterly
# 1509  Bank Transfer              Quarterly

# %%
len(df)
# Out:
# 5050

# %%
# delete duplicate records
df=df.drop_duplicates(subset =['Customer ID'],keep='first')

# %%
len(df)
# Out:
# 5000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.count()
# Out:
# Customer ID               5000
# Age                       5000
# Gender                    5000
# Item Purchased            5000
# Category                  5000
# Purchase Amount (USD)     5000
# Location                  5000
# Size                      5000
# Color                     5000
# Season                    5000
# Review Rating             5000
# Subscription Status       5000
# Shipping Type             5000
# Discount Applied          5000
# Previous Purchases        5000
# Payment Method            5000
# Frequency of Purchases    5000
# dtype: int64

# %% [markdown]
# # RENAMING THE HEADERS

# %%
df.columns=df.columns.str.replace(" ","_")
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
#replacing purchased_amount_(usd) to purchased_amount
df=df.rename(columns={"purchase_amount_(usd)":"purchase_amount"})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# # CONNNECTING TO SQL SERVER

# %%
# !pip install pyodbc sqlalchemy
# Out:
# Collecting pyodbc
#   Downloading pyodbc-5.3.0-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: sqlalchemy in C:\Users\ashut\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.0.49)
# Requirement already satisfied: greenlet>=1 in C:\Users\ashut\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\ashut\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading pyodbc-5.3.0-cp313-cp313-win_amd64.whl (70 kB)
# Installing collected packages: pyodbc
# Successfully installed pyodbc-5.3.0

# %%
import pymysql

# REPLACE THE PORT BELOW with the 5-digit number from your Ngrok terminal!
NGROK_PORT = 14925  # <--- Change this!

try:
    connection = pymysql.connect(
        host='0.tcp.ngrok.io',
        port=NGROK_PORT,
        user='root',
        password='Titanium22@',
        db='customer_behaviour_db',
        connect_timeout=10 # Gives it a bit more time to breathe
    )
    print("✔ Successfully connected to MySQL via Ngrok!")
except Exception as e:
    print(f"❌ Connection failed: {e}")
# Out:
# ❌ Connection failed: (2003, "Can't connect to MySQL server on '0.tcp.ngrok.io' ([WinError 10061] No connection could be made because the target machine actively refused it)")

# %%
import pymysql
from sqlalchemy import create_engine
import urllib.parse

# Credentials
user = 'root'
password = 'Titanium22@'
host = '127.0.0.1'
database = 'customer_analysis_db'

# Handle the '@' in password
safe_password = urllib.parse.quote_plus(password)

try:# Connection string
    engine = create_engine(f"mysql+pymysql://{user}:{safe_password}@{host}/{database}")
    print("✔ Library found and Connected Successfully!")
except Exception as e:
    print(f"❌ Error: {e}")
    print(f"❌ Error: {e}")
# Out:
# ✔ Library found and Connected Successfully!

# %%
import sys
# !{sys.executable} -m pip install pymysql sqlalchemy
# Out:
# Requirement already satisfied: pymysql in c:\Users\ashut\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.1.2)
# Requirement already satisfied: sqlalchemy in c:\Users\ashut\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.0.49)
# Requirement already satisfied: greenlet>=1 in c:\Users\ashut\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\Users\ashut\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy) (4.15.0)

# %%
table_name = "customer_behaviour_analysis"
df.to_sql(table_name,engine,if_exists="replace",index=False)
# Out:
# 5000
